# %% [markdown]
# ## test for adding EEG to python.

# %%
from metamers.eeg.ssvep2python import update_ssvep_storage, load_ssvep_npz
update_ssvep_storage()
# Out:
# [convert] MET000.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET000.npz
# [convert] MET000b.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET000b.npz
# [convert] MET001.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET001.npz
# [convert] MET002.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET002.npz
# [convert] MET002b.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET002b.npz
# [convert] MET003.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET003.npz
# [convert] MET003b.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET003b.npz
# [convert] MET004.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET004.npz
# [convert] MET004b.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET004b.npz
# [convert] MET005.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET005.npz
# [convert] MET005b.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET005b.npz
# [convert] MET006.mat → /home/zevaz/projects/metamers/eeg/ssveps/MET006.npz
# ...

# %%
from scipy.io import loadmat

mat = loadmat("/mnt/c/Users/zevaz/OneDrive/Escritorio/Metamers/eegExp/results/shareDarren/MET000.mat", squeeze_me=True, struct_as_record=False)
print(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Mar 17 12:26:44 2026', '__version__': '1.0', '__globals__': [], 'SubID': 'MET000', 'baseDIM': 'TR_RUN', 'baselines': array([[0.7368133 , 0.67339906, 0.66257774, 0.72022871],
#        [0.65642932, 0.83547143, 0.78388683, 0.66767143],
#        [0.76352961, 0.73081414, 0.62849712, 0.71002756],
#        [0.94537406, 0.60786075, 0.75037285, 0.73979617]]), 'greenArray': array([   0.        ,  222.22222222,  444.44444444,  666.66666667,
#         888.88888889, 1111.11111111, 1333.33333333, 1555.55555556,
#        1777.77777778, 2000.        ]), 'redArray': array([   0.        ,  355.55555556,  711.11111111, 1066.66666667,
#        1422.22222222, 1777.77777778, 2133.33333333, 2488.88888889,
#        2844.44444444, 3200.        ]), 'mapDIM': 'RED_GREEN_RUN', 'runMap': array([[[1.30339093, 0.86890625, 1.30139575, 1.22825022],
#         [1.39428011, 0.89125533, 1.22475015, 1.16224942],
# ...
