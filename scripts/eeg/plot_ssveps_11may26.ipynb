# %% [markdown]
# # preliminary plotting of ssveps on python

# %%
from metamers.eeg.ssvep2python import load_ssvep_npz
from metamers.eeg.ssvep_plotting import *

data = load_ssvep_npz("/home/zevaz/projects/metamers/eeg/ssveps/MET037.npz")

plot_single_run_map(data, run_idx=0)
plot_all_runs(data)
plot_combined_raw_map(data)
plot_normalized_maps(data)
plot_mean_normalized_map(data)
