# %%
from metamers.scores.FM100 import build_FM100_scores

df_scores = build_FM100_scores(save_csv=True)
print(df_scores.head())
# Out:
# FM100 scores saved to: /home/zevaz/projects/metamers/standardScores/FM100_scores.csv
#     SubID  Session Group Subgroup   TES   SqrtTES  PES_RG  PES_BY  \
# 0  MET000        1   CTR      NaN  36.0  6.000000    17.0    19.0
# 1  MET000        2   CTR      NaN  48.0  6.928203    14.0    34.0
# 2  MET000        3   CTR      NaN  20.0  4.472136     8.0    12.0
# 3  MET001        1   CTR      NaN  52.0  7.211103    20.0    31.0
# 4  MET002        1   CTR      NaN  24.0  4.898979     4.0    20.0
#
#    PES_RG_sqrt  PES_BY_sqrt  TES_tray1  TES_tray2  TES_tray3  TES_tray4  \
# 0     4.123106     4.358899        0.0       16.0       20.0        0.0
# 1     3.741657     5.830952        0.0       23.0       20.0        4.0
# 2     2.828427     3.464102        0.0        3.0       12.0        3.0
# 3     4.472136     5.567764       11.0       23.0        8.0        8.0
# 4     2.000000     4.472136        4.0       12.0        7.0        0.0
#
# ...
