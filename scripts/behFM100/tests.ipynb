# %% [markdown]
# ## Test for combining and saving data from different domains

# %%
from metamers.behFM100.combine import combine_behavioral_FM100

combined_df = combine_behavioral_FM100()
combined_df.head()
# Out:
# Saved combined behavioral + FM100 table to:
#  - /home/zevaz/projects/metamers/behFM100/behFM100_combined.csv
#  - /home/zevaz/projects/metamers/behFM100/behFM100_combined.parquet
#     SubID  Session Group Subgroup   TES   SqrtTES  PES_RG  PES_BY  \
# 0  MET000        1   CTR      NaN  36.0  6.000000    17.0    19.0
# 1  MET000        2   CTR      NaN  48.0  6.928203    14.0    34.0
# 2  MET000        3   CTR      NaN  20.0  4.472136     8.0    12.0
# 3  MET001        1   CTR      NaN  52.0  7.211103    20.0    31.0
# 4  MET002        1   CTR      NaN  24.0  4.898979     4.0    20.0
#
#    PES_RG_sqrt  PES_BY_sqrt  ...        cov_gg        cov_rg  ellipse_area  \
# 0     4.123106     4.358899  ...   8208.620901   9784.790450  46888.139765
# 1     3.741657     5.830952  ...   8208.620901   9784.790450  46888.139765
# 2     2.828427     3.464102  ...   8208.620901   9784.790450  46888.139765
# 3     4.472136     5.567764  ...  19866.350575  32397.333333  93994.500124
# ...

# %%
from metamers.behFM100.plots import (
    plot_combined_correlation,
    plot_angle_relationship,
    plot_spread_vs_severity,
    plot_anisotropy_vs_RG,
    plot_anisotropy_vs_BY,
    plot_entropy_vs_TES,
    plot_group_distributions
)

plot_combined_correlation(combined_df)
plot_angle_relationship(combined_df)
plot_spread_vs_severity(combined_df)
plot_anisotropy_vs_RG(combined_df)
plot_anisotropy_vs_BY(combined_df)
plot_entropy_vs_TES(combined_df)
plot_group_distributions(combined_df)
