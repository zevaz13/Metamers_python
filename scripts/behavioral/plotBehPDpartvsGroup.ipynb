# %% [markdown]
# Here we plot one participant agains a group

# %%
from metamers.behavioral.plotting import (
    load_behavior_table,
    plot_participant,
    plot_all_participants,
    plot_group,
    plot_all_participants_with_group,
    plot_participants,
    plot_participants_huemapped
)


df = load_behavior_table()
dfPD = df[df["PartType"] == 3]

plot_group(df, parttype=3, color="#534b7e")   # HC
plot_all_participants(dfPD)
# Out:
# /home/zevaz/projects/metamers/src/metamers/behavioral/plotting.py:87: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(

# %%
df = load_behavior_table()
dfPD = df[df["PartType"] == 3]

plot_all_participants_with_group(
    df,
    parttype=3,
    group_color="#96999a",
    participant_color="#ff6b35"
)
