# %%
from metamers.behavioral.plotting import (
    load_behavior_table,
    plot_participant,
    plot_all_participants,
    plot_group,
    plot_participants,
    plot_participants_huemapped
)



df = load_behavior_table()

plot_participant(df, subid="MET046")

# %%
dfPD = df[df["PartType"] == 3]
dfPD
# Out:
#        SubID     Red   Green  RunNumber  session  PartType       Date  \
# 639   MET025  1849.0  1012.0          1        1         3  29_APR_25
# 640   MET025  1439.0  1203.0          2        1         3  29_APR_25
# 641   MET025  1166.0  1158.0          3        1         3  29_APR_25
# 642   MET025  1358.0   666.0          4        1         3  29_APR_25
# 643   MET025  1323.0   675.0          5        1         3  29_APR_25
# ...      ...     ...     ...        ...      ...       ...        ...
# 1506  MET040  1358.0  1005.0         16        3         3  05_MAY_26
# 1507  MET040  1714.0   787.0         17        3         3  05_MAY_26
# 1508  MET040  2503.0  1504.0         18        3         3  05_MAY_26
# 1509  MET040  1570.0   986.0         19        3         3  05_MAY_26
# 1510  MET040  2088.0   590.0         20        3         3  05_MAY_26
#
#                 FolderOrg
# 639   S25_Beh_29_APR_25PD
# 640   S25_Beh_29_APR_25PD
# 641   S25_Beh_29_APR_25PD
# ...

# %%
from metamers.behavioral.plotting import (
    load_behavior_table,
    plot_participant,
    plot_all_participants,
    plot_group,
    plot_participants,
    plot_participants_huemapped
)



df = load_behavior_table()

plot_participant(df, subid="MET046")

# %%
plot_all_participants(dfPD)

# %%
plot_all_participants(df)
plot_group(df, parttype=1, color="#534b7e")   # HC

# %%
plot_group(df, parttype=2, color="#534b7e")   # CVD
plot_group(df, parttype=3, color="#714b47")   # PD

# %%
protans = ["MET016","MET017","MET028", "MET031", "MET036", "MET045", "MET046"]
plot_participants(df, subids=protans, color="#dd6666",title="protans")

# %%
deutans = ["MET015", "MET029", "MET032", "MET033", "MET034", "MET043", "MET044"]
plot_participants(df, subids=deutans, color="#10c1b9",title="deutans")

# %%
PDs = ["MET025", "MET030", "MET037","MET038","MET039","MET040","MET041","MET042"]
plot_participants_huemapped(df, subids=PDs, title="PDs")

# %%
deutans = ["MET015", "MET029", "MET032", "MET033", "MET034", "MET043", "MET044"]
plot_participants_huemapped(df, subids=deutans, title="Deutans")

# %%
protans = ["MET016","MET017","MET028", "MET031", "MET036", "MET045", "MET046"]
plot_participants_huemapped(df, subids=protans, title="Protans")
