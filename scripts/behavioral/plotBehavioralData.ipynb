# %%
from metamers.behavioral.plotting import (
    load_behavior_table,
    plot_participant,
    plot_all_participants,
    plot_group,
    plot_participants,
    plot_participants_huemapped
)



df = load_behavior_table()

plot_participant(df, subid="MET043")

# %%
from metamers.behavioral.plotting import (
    load_behavior_table,
    plot_participant,
    plot_all_participants,
    plot_group,
    plot_participants,
    plot_participants_huemapped
)



df = load_behavior_table()

plot_participant(df, subid="MET043")
# Out:
# /home/zevaz/projects/metamers/src/metamers/behavioral/plotting.py:31: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /home/zevaz/projects/metamers/src/metamers/behavioral/plotting.py:44: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Session")

# %%
plot_all_participants(df)
plot_group(df, parttype=1, color="#534b7e")   # HC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_all_participants(df)
#       2 plot_group(df, parttype=1, color="#534b7e")   # HC
#
# NameError: name 'plot_all_participants' is not defined

# %%
plot_group(df, parttype=2, color="#534b7e")   # CVD
plot_group(df, parttype=3, color="#714b47")   # PD
# Out:
# /home/zevaz/projects/metamers/src/metamers/behavioral/plotting.py:76: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# /home/zevaz/projects/metamers/src/metamers/behavioral/plotting.py:76: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(

# %%
protans = ["MET016","MET017","MET028", "MET031", "MET036"]
plot_participants(df, subids=protans, color="#dd6666",title="protans")

# %%
deutans = ["MET015", "MET029", "MET032", "MET033", "MET034"]
plot_participants(df, subids=deutans, color="#10c1b9",title="deutans")

# %%
PDs = ["MET025", "MET030", "MET037","MET038","MET039","MET040","MET041"]
plot_participants_huemapped(df, subids=PDs, title="PDs")
